# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.preprocessing import OrdinalEncoder
from sklearn.utils import shuffle
import pickle

from keras.models import Model
from keras.layers import Input, Embedding, Flatten, Dense, Concatenate
from keras.layers import Dropout, BatchNormalization, Activation,  Dot, Add
from keras.regularizers import l2
from keras.optimizers import SGD, Adam

# %%
from google.colab import  drive

drive.mount('/drive')
# Out:
# Drive already mounted at /drive; to attempt to forcibly remount, call drive.mount("/drive", force_remount=True).

# %%
df = pd.read_csv('/drive/MyDrive/Datasets/amazon_fashion/cleaned_amazon_fashion.csv')

# %%
# !pip install -q tensorflow-recommenders

# %%
import tensorflow_recommenders as tfrs
import tensorflow as tf
from typing import Dict, Text

# %%
df = tf.data.Dataset.from_tensor_slices(df[['asin', 'reviewerID']].to_dict(orient='list'))

# %%
ratings = df.map(lambda x: {
    "asin": x["asin"],
    "reviewerID": x["reviewerID"],
})
asin = df.map(lambda x: x["asin"])

# %%
tf.random.set_seed(42)
shuffled = ratings.shuffle(len(df), seed=42, reshuffle_each_iteration=False)
cutoff = int(0.8*len(df))
train = shuffled.take(cutoff)
test = shuffled.skip(cutoff).take(len(df) - cutoff)

# %%
asin_titles = asin.batch(len(df))
reviewerID = ratings.batch(len(df)).map(lambda x: x["reviewerID"])

unique_asin = np.unique(np.concatenate(list(asin_titles)))
unique_reviewerID = np.unique(np.concatenate(list(reviewerID)))

unique_asin[:10]
# Out:
# array([b'B000YFSR4W', b'B000YFSR5G', b'B0014F7B98', b'B001IKJOLW',
#        b'B0058YEJ5K', b'B005AGO4LU', b'B0092UF54A', b'B009MA34NY',
#        b'B010RRWKT4', b'B014IBJKNO'], dtype=object)

# %%
embedding_dimension = 32

# %%
user_model = tf.keras.Sequential([
  tf.keras.layers.StringLookup(
      vocabulary=unique_reviewerID, mask_token=None),
  # We add an additional embedding to account for unknown tokens.
  tf.keras.layers.Embedding(len(unique_reviewerID) + 1, embedding_dimension)
])

# %%
fashion_model = tf.keras.Sequential([
  tf.keras.layers.StringLookup(
      vocabulary=unique_asin, mask_token=None),
  tf.keras.layers.Embedding(len(unique_asin) + 1, embedding_dimension)
])

# %%
metrics = tfrs.metrics.FactorizedTopK(
  candidates=asin.batch(128).map(fashion_model)
)

# %%
task = tfrs.tasks.Retrieval(
  metrics=metrics
)

# %%
class FashionModel(tfrs.Model):

  def __init__(self, user_model, fashion_model):
    super().__init__()
    self.fashion_model: tf.keras.Model = fashion_model
    self.user_model: tf.keras.Model = user_model
    self.task: tf.keras.layers.Layer = task

  def compute_loss(self, features: Dict[Text, tf.Tensor], training=False) -> tf.Tensor:
    # We pick out the user features and pass them into the user model.
    user_embeddings = self.user_model(features["reviewerID"])
    # And pick out the movie features and pass them into the movie model,
    # getting embeddings back.
    positive_fashion_embeddings = self.fashion_model(features["asin"])

    # The task computes the loss and the metrics.
    return self.task(user_embeddings, positive_fashion_embeddings)

# %%
FashionModel(user_model,fashion_model)

# %%
user_model

# %%
class NoBaseClassFashionModel(tf.keras.Model):

  def __init__(self, user_model, fashion_model):
    super().__init__()
    self.fashion_model: tf.keras.Model = fashion_model
    self.user_model: tf.keras.Model = user_model
    self.task: tf.keras.layers.Layer = task

  def train_step(self, features: Dict[Text, tf.Tensor]) -> tf.Tensor:

    # Set up a gradient tape to record gradients.
    with tf.GradientTape() as tape:

      # Loss computation.
      user_embeddings = self.user_model(features["reviewerID"])
      positive_fashion_embeddings = self.fashion_model(features["asin"])
      loss = self.task(user_embeddings, positive_fashion_embeddings)

      # Handle regularization losses as well.
      regularization_loss = sum(self.losses)

      total_loss = loss + regularization_loss

    gradients = tape.gradient(total_loss, self.trainable_variables)
    self.optimizer.apply_gradients(zip(gradients, self.trainable_variables))

    metrics = {metric.name: metric.result() for metric in self.metrics}
    metrics["loss"] = loss
    metrics["regularization_loss"] = regularization_loss
    metrics["total_loss"] = total_loss

    return metrics

  def test_step(self, features: Dict[Text, tf.Tensor]) -> tf.Tensor:

    # Loss computation.
    user_embeddings = self.user_model(features["reviewerID"])
    positive_fashion_embeddings = self.fashion_model(features["asin"])
    loss = self.task(user_embeddings, positive_fashion_embeddings)

    # Handle regularization losses as well.
    regularization_loss = sum(self.losses)

    total_loss = loss + regularization_loss

    metrics = {metric.name: metric.result() for metric in self.metrics}
    metrics["loss"] = loss
    metrics["regularization_loss"] = regularization_loss
    metrics["total_loss"] = total_loss

    return metrics

# %%
metrics

# %%
NoBaseClassFashionModel(user_model,fashion_model)

# %%
metrics.variables
# Out:
# [<tf.Variable 'counter:0' shape=() dtype=int32, numpy=0>]

# %%
model = FashionModel(user_model, fashion_model)
model.compile(optimizer=tf.keras.optimizers.Adagrad(learning_rate=0.1))

# %%
cached_train = train.shuffle(len(df)).batch(2500).cache()
cached_test = test.batch(522).cache()

# %%
len(df)-2500
# Out:
# 522

# %%
model.fit(cached_train, epochs=30)
# Out:
# Epoch 1/30
# 1/1 [==============================] - 1s 605ms/step - factorized_top_k/top_1_categorical_accuracy: 0.1341 - factorized_top_k/top_5_categorical_accuracy: 0.1341 - factorized_top_k/top_10_categorical_accuracy: 0.1341 - factorized_top_k/top_50_categorical_accuracy: 0.1481 - factorized_top_k/top_100_categorical_accuracy: 0.1481 - loss: 18164.4082 - regularization_loss: 0.0000e+00 - total_loss: 18164.4082
# Epoch 2/30
# 1/1 [==============================] - 1s 630ms/step - factorized_top_k/top_1_categorical_accuracy: 0.1427 - factorized_top_k/top_5_categorical_accuracy: 0.1427 - factorized_top_k/top_10_categorical_accuracy: 0.1427 - factorized_top_k/top_50_categorical_accuracy: 0.1531 - factorized_top_k/top_100_categorical_accuracy: 0.1531 - loss: 18164.5078 - regularization_loss: 0.0000e+00 - total_loss: 18164.5078
# Epoch 3/30
# 1/1 [==============================] - 1s 610ms/step - factorized_top_k/top_1_categorical_accuracy: 0.1423 - factorized_top_k/top_5_categorical_accuracy: 0.1423 - factorized_top_k/top_10_categorical_accuracy: 0.1423 - factorized_top_k/top_50_categorical_accuracy: 0.1552 - factorized_top_k/top_100_categorical_accuracy: 0.1552 - loss: 18164.2715 - regularization_loss: 0.0000e+00 - total_loss: 18164.2715
# Epoch 4/30
# 1/1 [==============================] - 1s 617ms/step - factorized_top_k/top_1_categorical_accuracy: 0.1816 - factorized_top_k/top_5_categorical_accuracy: 0.1816 - factorized_top_k/top_10_categorical_accuracy: 0.1816 - factorized_top_k/top_50_categorical_accuracy: 0.1949 - factorized_top_k/top_100_categorical_accuracy: 0.1949 - loss: 18164.1367 - regularization_loss: 0.0000e+00 - total_loss: 18164.1367
# Epoch 5/30
# 1/1 [==============================] - 1s 646ms/step - factorized_top_k/top_1_categorical_accuracy: 0.1444 - factorized_top_k/top_5_categorical_accuracy: 0.1444 - factorized_top_k/top_10_categorical_accuracy: 0.1444 - factorized_top_k/top_50_categorical_accuracy: 0.1568 - factorized_top_k/top_100_categorical_accuracy: 0.1568 - loss: 18163.6855 - regularization_loss: 0.0000e+00 - total_loss: 18163.6855
# Epoch 6/30
# 1/1 [==============================] - 1s 612ms/step - factorized_top_k/top_1_categorical_accuracy: 0.1394 - factorized_top_k/top_5_categorical_accuracy: 0.1394 - factorized_top_k/top_10_categorical_accuracy: 0.1394 - factorized_top_k/top_50_categorical_accuracy: 0.1535 - factorized_top_k/top_100_categorical_accuracy: 0.1535 - loss: 18163.2598 - regularization_loss: 0.0000e+00 - total_loss: 18163.2598
# Epoch 7/30
# 1/1 [==============================] - 1s 630ms/step - factorized_top_k/top_1_categorical_accuracy: 0.1626 - factorized_top_k/top_5_categorical_accuracy: 0.1626 - factorized_top_k/top_10_categorical_accuracy: 0.1626 - factorized_top_k/top_50_categorical_accuracy: 0.1705 - factorized_top_k/top_100_categorical_accuracy: 0.1705 - loss: 18162.6426 - regularization_loss: 0.0000e+00 - total_loss: 18162.6426
# Epoch 8/30
# 1/1 [==============================] - 1s 607ms/step - factorized_top_k/top_1_categorical_accuracy: 0.1353 - factorized_top_k/top_5_categorical_accuracy: 0.1353 - factorized_top_k/top_10_categorical_accuracy: 0.1353 - factorized_top_k/top_50_categorical_accuracy: 0.1469 - factorized_top_k/top_100_categorical_accuracy: 0.1469 - loss: 18162.1387 - regularization_loss: 0.0000e+00 - total_loss: 18162.1387
# Epoch 9/30
# 1/1 [==============================] - 1s 628ms/step - factorized_top_k/top_1_categorical_accuracy: 0.1651 - factorized_top_k/top_5_categorical_accuracy: 0.1651 - factorized_top_k/top_10_categorical_accuracy: 0.1651 - factorized_top_k/top_50_categorical_accuracy: 0.1874 - factorized_top_k/top_100_categorical_accuracy: 0.1874 - loss: 18161.5840 - regularization_loss: 0.0000e+00 - total_loss: 18161.5840
# Epoch 10/30
# 1/1 [==============================] - 1s 632ms/step - factorized_top_k/top_1_categorical_accuracy: 0.1249 - factorized_top_k/top_5_categorical_accuracy: 0.1249 - factorized_top_k/top_10_categorical_accuracy: 0.1249 - factorized_top_k/top_50_categorical_accuracy: 0.1361 - factorized_top_k/top_100_categorical_accuracy: 0.1361 - loss: 18161.2070 - regularization_loss: 0.0000e+00 - total_loss: 18161.2070
# Epoch 11/30
# 1/1 [==============================] - 1s 610ms/step - factorized_top_k/top_1_categorical_accuracy: 0.1721 - factorized_top_k/top_5_categorical_accuracy: 0.1721 - factorized_top_k/top_10_categorical_accuracy: 0.1721 - factorized_top_k/top_50_categorical_accuracy: 0.1961 - factorized_top_k/top_100_categorical_accuracy: 0.1961 - loss: 18160.8359 - regularization_loss: 0.0000e+00 - total_loss: 18160.8359
# Epoch 12/30
# 1/1 [==============================] - 1s 612ms/step - factorized_top_k/top_1_categorical_accuracy: 0.1283 - factorized_top_k/top_5_categorical_accuracy: 0.1283 - factorized_top_k/top_10_categorical_accuracy: 0.1283 - factorized_top_k/top_50_categorical_accuracy: 0.1398 - factorized_top_k/top_100_categorical_accuracy: 0.1398 - loss: 18160.6445 - regularization_loss: 0.0000e+00 - total_loss: 18160.6445
# Epoch 13/30
# 1/1 [==============================] - 1s 607ms/step - factorized_top_k/top_1_categorical_accuracy: 0.1779 - factorized_top_k/top_5_categorical_accuracy: 0.1779 - factorized_top_k/top_10_categorical_accuracy: 0.1779 - factorized_top_k/top_50_categorical_accuracy: 0.1978 - factorized_top_k/top_100_categorical_accuracy: 0.1978 - loss: 18160.4434 - regularization_loss: 0.0000e+00 - total_loss: 18160.4434
# Epoch 14/30
# 1/1 [==============================] - 1s 615ms/step - factorized_top_k/top_1_categorical_accuracy: 0.1460 - factorized_top_k/top_5_categorical_accuracy: 0.1460 - factorized_top_k/top_10_categorical_accuracy: 0.1460 - factorized_top_k/top_50_categorical_accuracy: 0.1576 - factorized_top_k/top_100_categorical_accuracy: 0.1576 - loss: 18160.3848 - regularization_loss: 0.0000e+00 - total_loss: 18160.3848
# Epoch 15/30
# 1/1 [==============================] - 1s 608ms/step - factorized_top_k/top_1_categorical_accuracy: 0.1787 - factorized_top_k/top_5_categorical_accuracy: 0.1787 - factorized_top_k/top_10_categorical_accuracy: 0.1787 - factorized_top_k/top_50_categorical_accuracy: 0.1899 - factorized_top_k/top_100_categorical_accuracy: 0.1899 - loss: 18160.2676 - regularization_loss: 0.0000e+00 - total_loss: 18160.2676
# Epoch 16/30
# 1/1 [==============================] - 1s 598ms/step - factorized_top_k/top_1_categorical_accuracy: 0.1212 - factorized_top_k/top_5_categorical_accuracy: 0.1212 - factorized_top_k/top_10_categorical_accuracy: 0.1212 - factorized_top_k/top_50_categorical_accuracy: 0.1291 - factorized_top_k/top_100_categorical_accuracy: 0.1291 - loss: 18160.2285 - regularization_loss: 0.0000e+00 - total_loss: 18160.2285
# Epoch 17/30
# 1/1 [==============================] - 1s 601ms/step - factorized_top_k/top_1_categorical_accuracy: 0.1663 - factorized_top_k/top_5_categorical_accuracy: 0.1663 - factorized_top_k/top_10_categorical_accuracy: 0.1663 - factorized_top_k/top_50_categorical_accuracy: 0.1754 - factorized_top_k/top_100_categorical_accuracy: 0.1754 - loss: 18160.0684 - regularization_loss: 0.0000e+00 - total_loss: 18160.0684
# Epoch 18/30
# 1/1 [==============================] - 1s 603ms/step - factorized_top_k/top_1_categorical_accuracy: 0.1005 - factorized_top_k/top_5_categorical_accuracy: 0.1005 - factorized_top_k/top_10_categorical_accuracy: 0.1005 - factorized_top_k/top_50_categorical_accuracy: 0.1258 - factorized_top_k/top_100_categorical_accuracy: 0.1258 - loss: 18159.9395 - regularization_loss: 0.0000e+00 - total_loss: 18159.9395
# Epoch 19/30
# 1/1 [==============================] - 1s 611ms/step - factorized_top_k/top_1_categorical_accuracy: 0.1249 - factorized_top_k/top_5_categorical_accuracy: 0.1249 - factorized_top_k/top_10_categorical_accuracy: 0.1249 - factorized_top_k/top_50_categorical_accuracy: 0.1804 - factorized_top_k/top_100_categorical_accuracy: 0.1804 - loss: 18159.6914 - regularization_loss: 0.0000e+00 - total_loss: 18159.6914
# Epoch 20/30
# 1/1 [==============================] - 1s 626ms/step - factorized_top_k/top_1_categorical_accuracy: 0.1101 - factorized_top_k/top_5_categorical_accuracy: 0.1101 - factorized_top_k/top_10_categorical_accuracy: 0.1101 - factorized_top_k/top_50_categorical_accuracy: 0.1163 - factorized_top_k/top_100_categorical_accuracy: 0.1163 - loss: 18159.4629 - regularization_loss: 0.0000e+00 - total_loss: 18159.4629
# Epoch 21/30
# 1/1 [==============================] - 1s 612ms/step - factorized_top_k/top_1_categorical_accuracy: 0.1585 - factorized_top_k/top_5_categorical_accuracy: 0.1585 - factorized_top_k/top_10_categorical_accuracy: 0.1585 - factorized_top_k/top_50_categorical_accuracy: 0.1663 - factorized_top_k/top_100_categorical_accuracy: 0.1663 - loss: 18159.1777 - regularization_loss: 0.0000e+00 - total_loss: 18159.1777
# Epoch 22/30
# 1/1 [==============================] - 1s 623ms/step - factorized_top_k/top_1_categorical_accuracy: 0.1444 - factorized_top_k/top_5_categorical_accuracy: 0.1444 - factorized_top_k/top_10_categorical_accuracy: 0.1444 - factorized_top_k/top_50_categorical_accuracy: 0.1506 - factorized_top_k/top_100_categorical_accuracy: 0.1506 - loss: 18158.9102 - regularization_loss: 0.0000e+00 - total_loss: 18158.9102
# Epoch 23/30
# 1/1 [==============================] - 1s 628ms/step - factorized_top_k/top_1_categorical_accuracy: 0.1576 - factorized_top_k/top_5_categorical_accuracy: 0.1576 - factorized_top_k/top_10_categorical_accuracy: 0.1576 - factorized_top_k/top_50_categorical_accuracy: 0.1671 - factorized_top_k/top_100_categorical_accuracy: 0.1671 - loss: 18158.6523 - regularization_loss: 0.0000e+00 - total_loss: 18158.6523
# Epoch 24/30
# 1/1 [==============================] - 1s 581ms/step - factorized_top_k/top_1_categorical_accuracy: 0.1543 - factorized_top_k/top_5_categorical_accuracy: 0.1543 - factorized_top_k/top_10_categorical_accuracy: 0.1543 - factorized_top_k/top_50_categorical_accuracy: 0.1618 - factorized_top_k/top_100_categorical_accuracy: 0.1618 - loss: 18158.4141 - regularization_loss: 0.0000e+00 - total_loss: 18158.4141
# Epoch 25/30
# 1/1 [==============================] - 1s 621ms/step - factorized_top_k/top_1_categorical_accuracy: 0.1332 - factorized_top_k/top_5_categorical_accuracy: 0.1332 - factorized_top_k/top_10_categorical_accuracy: 0.1332 - factorized_top_k/top_50_categorical_accuracy: 0.1609 - factorized_top_k/top_100_categorical_accuracy: 0.1609 - loss: 18158.2305 - regularization_loss: 0.0000e+00 - total_loss: 18158.2305
# Epoch 26/30
# 1/1 [==============================] - 1s 602ms/step - factorized_top_k/top_1_categorical_accuracy: 0.1580 - factorized_top_k/top_5_categorical_accuracy: 0.1580 - factorized_top_k/top_10_categorical_accuracy: 0.1580 - factorized_top_k/top_50_categorical_accuracy: 0.1655 - factorized_top_k/top_100_categorical_accuracy: 0.1655 - loss: 18158.0508 - regularization_loss: 0.0000e+00 - total_loss: 18158.0508
# Epoch 27/30
# 1/1 [==============================] - 1s 618ms/step - factorized_top_k/top_1_categorical_accuracy: 0.1183 - factorized_top_k/top_5_categorical_accuracy: 0.1183 - factorized_top_k/top_10_categorical_accuracy: 0.1183 - factorized_top_k/top_50_categorical_accuracy: 0.1262 - factorized_top_k/top_100_categorical_accuracy: 0.1274 - loss: 18157.9551 - regularization_loss: 0.0000e+00 - total_loss: 18157.9551
# Epoch 28/30
# 1/1 [==============================] - 1s 607ms/step - factorized_top_k/top_1_categorical_accuracy: 0.1237 - factorized_top_k/top_5_categorical_accuracy: 0.1237 - factorized_top_k/top_10_categorical_accuracy: 0.1237 - factorized_top_k/top_50_categorical_accuracy: 0.1324 - factorized_top_k/top_100_categorical_accuracy: 0.1324 - loss: 18157.8613 - regularization_loss: 0.0000e+00 - total_loss: 18157.8613
# Epoch 29/30
# 1/1 [==============================] - 1s 620ms/step - factorized_top_k/top_1_categorical_accuracy: 0.1171 - factorized_top_k/top_5_categorical_accuracy: 0.1171 - factorized_top_k/top_10_categorical_accuracy: 0.1171 - factorized_top_k/top_50_categorical_accuracy: 0.1361 - factorized_top_k/top_100_categorical_accuracy: 0.1361 - loss: 18157.8574 - regularization_loss: 0.0000e+00 - total_loss: 18157.8574
# Epoch 30/30
# 1/1 [==============================] - 1s 613ms/step - factorized_top_k/top_1_categorical_accuracy: 0.1254 - factorized_top_k/top_5_categorical_accuracy: 0.1254 - factorized_top_k/top_10_categorical_accuracy: 0.1254 - factorized_top_k/top_50_categorical_accuracy: 0.1336 - factorized_top_k/top_100_categorical_accuracy: 0.1336 - loss: 18157.8496 - regularization_loss: 0.0000e+00 - total_loss: 18157.8496

# %%
model.evaluate(cached_test, return_dict=True)
# Out:
# 1/1 [==============================] - 0s 232ms/step - factorized_top_k/top_1_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_5_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_10_categorical_accuracy: 0.0000e+00 - factorized_top_k/top_50_categorical_accuracy: 0.0083 - factorized_top_k/top_100_categorical_accuracy: 0.0083 - loss: 5529.1992 - regularization_loss: 0.0000e+00 - total_loss: 5529.1992
# {'factorized_top_k/top_1_categorical_accuracy': 0.0,
#  'factorized_top_k/top_5_categorical_accuracy': 0.0,
#  'factorized_top_k/top_10_categorical_accuracy': 0.0,
#  'factorized_top_k/top_50_categorical_accuracy': 0.00826446246355772,
#  'factorized_top_k/top_100_categorical_accuracy': 0.00826446246355772,
#  'loss': 5529.19921875,
#  'regularization_loss': 0,
#  'total_loss': 5529.19921875}

# %%
model.evaluate_generator
# Out:
# <bound method Model.evaluate_generator of <__main__.FashionModel object at 0x7faeb1651910>>

# %%
model.predict
# Out:
# <bound method Model.predict of <__main__.FashionModel object at 0x7faeb1651910>>

# %%
model.predict(cached_test)

# %%
len(df) -3000
# Out:
# 22

# %%
df1 = pd.read_csv('/drive/MyDrive/Datasets/amazon_fashion/cleaned_amazon_fashion.csv')

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3022 entries, 0 to 3021
# Data columns (total 12 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Unnamed: 0      3022 non-null   int64
#  1   overall         3022 non-null   float64
#  2   verified        3022 non-null   bool
#  3   reviewTime      3022 non-null   object
#  4   reviewerID      3022 non-null   object
#  5   asin            3022 non-null   object
#  6   reviewerName    3022 non-null   object
#  7   reviewText      3006 non-null   object
#  8   summary         3022 non-null   object
#  9   unixReviewTime  3022 non-null   int64
#  10  size            3009 non-null   object
#  11  color           3009 non-null   object
# dtypes: bool(1), float64(1), int64(2), object(8)
# memory usage: 262.8+ KB

# %%
df1 = tf.data.Dataset.from_tensor_slices(df1[['asin', 'reviewerID','overall']].to_dict(orient='list'))

# %%
ratings1 = df1.map(lambda x: {
     "asin": x["asin"],
     "reviewerID": x["reviewerID"],
     "overall": x["overall"]
})

# %%
tf.random.set_seed(42)
shuffled = ratings1.shuffle(len(df1), seed=42, reshuffle_each_iteration=False)
cutoff = int(0.8*len(df))
train1 = shuffled.take(cutoff)
test1 = shuffled.skip(cutoff).take(len(df1) - cutoff)

# %%
asin = ratings1.batch(len(df1)).map(lambda x: x["asin"])
reviewerID = ratings.batch(len(df1)).map(lambda x: x["reviewerID"])

unique_asin = np.unique(np.concatenate(list(asin)))
unique_reviewerID = np.unique(np.concatenate(list(reviewerID)))

# %%
class RankingModel(tf.keras.Model):

  def __init__(self):
    super().__init__()
    embedding_dimension = 32

    # Compute embeddings for users.
    self.user_embeddings = tf.keras.Sequential([
      tf.keras.layers.StringLookup(
        vocabulary=unique_reviewerID, mask_token=None),
      tf.keras.layers.Embedding(len(unique_reviewerID) + 1, embedding_dimension)
    ])

    # Compute embeddings for asin.
    self.movie_embeddings = tf.keras.Sequential([
      tf.keras.layers.StringLookup(
        vocabulary=unique_asin, mask_token=None),
      tf.keras.layers.Embedding(len(unique_asin) + 1, embedding_dimension)
    ])

    # Compute predictions.
    self.ratings = tf.keras.Sequential([
      # Learn multiple dense layers.
      tf.keras.layers.Dense(256, activation="relu"),
      tf.keras.layers.Dense(64, activation="relu"),
      # Make rating predictions in the final layer.
      tf.keras.layers.Dense(1)
  ])

  def call(self, inputs):

    reviewerID, asin = inputs

    user_embedding = self.user_embeddings(reviewerID)
    asin_embedding = self.movie_embeddings(asin)

    return self.ratings(tf.concat([user_embedding, asin_embedding], axis=1))

# %%
RankingModel()((["A3DDWDH9PX2YX2"], ["B000K2PJ4K"]))
# Out:
# WARNING:tensorflow:Layers in a Sequential model should only have a single input tensor. Received: inputs=['A3DDWDH9PX2YX2']. Consider rewriting this model with the Functional API.
# WARNING:tensorflow:Layers in a Sequential model should only have a single input tensor. Received: inputs=['B000K2PJ4K']. Consider rewriting this model with the Functional API.
# <tf.Tensor: shape=(1, 1), dtype=float32, numpy=array([[-0.01580527]], dtype=float32)>

# %%
task = tfrs.tasks.Ranking(
  loss = tf.keras.losses.MeanSquaredError(),
  metrics=[tf.keras.metrics.RootMeanSquaredError()]
)

# %%
class MovielensModel(tfrs.models.Model):

  def __init__(self):
    super().__init__()
    self.ranking_model: tf.keras.Model = FashionModel(user_model , fashion_model)
    self.task: tf.keras.layers.Layer = tfrs.tasks.Ranking(
      loss = tf.keras.losses.MeanSquaredError(),
      metrics=[tf.keras.metrics.RootMeanSquaredError()]
    )

  def call(self, features: Dict[str, tf.Tensor]) -> tf.Tensor:
    return self.ranking_model(
        (features["reviewerID"], features["asin"]))

  def compute_loss(self, features: Dict[Text, tf.Tensor], training=False) -> tf.Tensor:
    labels = features.pop("overall")

    rating_predictions = self(features)

    # The task computes the loss and the metrics.
    return self.task(labels=labels, predictions=rating_predictions)

# %%
model = MovielensModel()
model.compile(optimizer=tf.keras.optimizers.Adagrad(learning_rate=0.1))

# %%
cached_train1 = train1.shuffle(len(df1)).batch(2417).cache()
cached_test1 = test1.batch(605).cache()

# %%
cached_train1
# Out:
# <CacheDataset element_spec={'asin': TensorSpec(shape=(None,), dtype=tf.string, name=None), 'reviewerID': TensorSpec(shape=(None,), dtype=tf.string, name=None), 'overall': TensorSpec(shape=(None,), dtype=tf.float32, name=None)}>

# %%
model.fit(cached_train1, epochs=3)

# %%
model.evaluate(cached_test1, return_dict=True)
# Out:
# 1/1 [==============================] - 0s 109ms/step - root_mean_squared_error: 2.0440 - loss: 4.1779 - regularization_loss: 0.0000e+00 - total_loss: 4.1779
# {'root_mean_squared_error': 2.0439889430999756,
#  'loss': 4.177891254425049,
#  'regularization_loss': 0,
#  'total_loss': 4.177891254425049}

# %%
test_ratings = {}
test_asin = ["B000K2PJ4K", "B00G8Q7JZ4", "B00GKF5BAS"]
for asin in test_asin:
  test_ratings[asin] = model({
      "reviewerID": np.array(["A3DDWDH9PX2YX2"]),
      "asin": np.array([asin])
  })

print("overall:")
for title, score in sorted(test_ratings.items(), key=lambda x: x[1], reverse=True):
  print(f"{title}: {score}")
# Out:
# overall:
# B000K2PJ4K: [[5.4934473]]
# B00G8Q7JZ4: [[5.4934473]]
# B00GKF5BAS: [[5.4934473]]
